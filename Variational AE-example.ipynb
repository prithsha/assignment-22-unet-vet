# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from torchvision.utils import save_image

# %%
# Define hyperparameters
image_size = 784
hidden_dim = 400
latent_dim = 20
batch_size = 128
epochs = 25

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root='data',
                                           train=True,
                                           transform=transforms.ToTensor(),
                                           download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_dataset = torchvision.datasets.MNIST(root='data',
                                          train=False,
                                          transform=transforms.ToTensor())

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=True)

# Create directory to save the reconstructed and sampled images (if directory not present)
sample_dir = 'results'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# ![vae](https://user-images.githubusercontent.com/30661597/78418103-a2047200-766b-11ea-8205-c7e5712715f4.png)

# %%
# VAE model
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        
        self.fc1 = nn.Linear(image_size, hidden_dim)
        self.fc2_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc2_logvar = nn.Linear(hidden_dim, latent_dim)
        self.fc3 = nn.Linear(latent_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, image_size)
        
    def encode(self, x):
        h = F.relu(self.fc1(x))
        mu = self.fc2_mean(h)
        log_var = self.fc2_logvar(h)
        return mu, log_var
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(logvar/2)
        eps = torch.randn_like(std)
        return mu + eps * std
    
    def decode(self, z):
        h = F.relu(self.fc3(z))
        out = torch.sigmoid(self.fc4(h))
        return out
    
    def forward(self, x):
        # x: (batch_size, 1, 28,28) --> (batch_size, 784)
        mu, logvar = self.encode(x.view(-1, image_size))
        z = self.reparameterize(mu, logvar)
        reconstructed = self.decode(z)
        return reconstructed, mu, logvar

# Define model and optimizer
model = VAE().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# $Loss = -E[\log P(X | z)]+D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]$

# %% [markdown]
# #### $D_{K L}[N(\mu(X), \Sigma(X)) \| N(0,1)]=\frac{1}{2} \sum_{k}\left(\exp (\Sigma(X))+\mu^{2}(X)-1-\Sigma(X)\right)$

# %%
# Define Loss
def loss_function(reconstructed_image, original_image, mu, logvar):
    bce = F.binary_cross_entropy(reconstructed_image, original_image.view(-1, 784), reduction = 'sum')
    # kld = torch.sum(0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar, 1))
    kld = 0.5 * torch.sum(logvar.exp() + mu.pow(2) - 1 - logvar)
    return bce + kld
    

# Train function
def train(epoch):
    model.train()
    train_loss = 0
    for i, (images, _) in enumerate(train_loader):
        images = images.to(device)
        reconstructed, mu, logvar = model(images)
        loss = loss_function(reconstructed, images, mu, logvar)
        optimizer.zero_grad()
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        
        if i % 100 == 0:
            print("Train Epoch {} [Batch {}/{}]\tLoss: {:.3f}".format(epoch, i, len(train_loader), loss.item()/len(images)))
            
    print('=====> Epoch {}, Average Loss: {:.3f}'.format(epoch, train_loss/len(train_loader.dataset)))


# Test function
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_idx, (images, _) in enumerate(test_loader):
            images = images.to(device)
            reconstructed, mu, logvar = model(images)
            test_loss += loss_function(reconstructed, images, mu, logvar).item()
            if batch_idx == 0:
                comparison = torch.cat([images[:5], reconstructed.view(batch_size, 1, 28, 28)[:5]])
                save_image(comparison.cpu(), 'results/reconstruction_' + str(epoch) + '.png', nrow = 5)

    print('=====> Average Test Loss: {:.3f}'.format(test_loss/len(test_loader.dataset)))

# %%
# Main function
for epoch in range(1, epochs + 1):
    train(epoch)
    test(epoch)
    with torch.no_grad():
        # Get rid of the encoder and sample z from the gaussian ditribution and feed it to the decoder to generate samples
        sample = torch.randn(64,20).to(device)
        generated = model.decode(sample).cpu()
        save_image(generated.view(64,1,28,28), 'results/sample_' + str(epoch) + '.png')
# Out:
# Train Epoch 1 [Batch 0/469]	Loss: 549.587
# Train Epoch 1 [Batch 100/469]	Loss: 179.872
# Train Epoch 1 [Batch 200/469]	Loss: 154.018
# Train Epoch 1 [Batch 300/469]	Loss: 139.495
# Train Epoch 1 [Batch 400/469]	Loss: 130.869
# =====> Epoch 1, Average Loss: 165.207
# =====> Average Test Loss: 127.736
# Train Epoch 2 [Batch 0/469]	Loss: 128.480
# Train Epoch 2 [Batch 100/469]	Loss: 126.887
# Train Epoch 2 [Batch 200/469]	Loss: 119.165
# Train Epoch 2 [Batch 300/469]	Loss: 115.867
# Train Epoch 2 [Batch 400/469]	Loss: 116.618
# =====> Epoch 2, Average Loss: 121.383
# =====> Average Test Loss: 115.866
# Train Epoch 3 [Batch 0/469]	Loss: 118.904
# Train Epoch 3 [Batch 100/469]	Loss: 117.721
# Train Epoch 3 [Batch 200/469]	Loss: 113.887
# Train Epoch 3 [Batch 300/469]	Loss: 112.577
# Train Epoch 3 [Batch 400/469]	Loss: 110.876
# =====> Epoch 3, Average Loss: 114.565
# =====> Average Test Loss: 111.669
# Train Epoch 4 [Batch 0/469]	Loss: 111.404
# Train Epoch 4 [Batch 100/469]	Loss: 111.501
# Train Epoch 4 [Batch 200/469]	Loss: 108.256
# Train Epoch 4 [Batch 300/469]	Loss: 114.737
# Train Epoch 4 [Batch 400/469]	Loss: 106.494
# =====> Epoch 4, Average Loss: 111.648
# =====> Average Test Loss: 109.611
# Train Epoch 5 [Batch 0/469]	Loss: 112.231
# Train Epoch 5 [Batch 100/469]	Loss: 113.313
# Train Epoch 5 [Batch 200/469]	Loss: 110.724
# Train Epoch 5 [Batch 300/469]	Loss: 112.030
# Train Epoch 5 [Batch 400/469]	Loss: 111.305
# =====> Epoch 5, Average Loss: 109.884
# =====> Average Test Loss: 108.369
# Train Epoch 6 [Batch 0/469]	Loss: 109.300
# Train Epoch 6 [Batch 100/469]	Loss: 106.870
# Train Epoch 6 [Batch 200/469]	Loss: 104.788
# Train Epoch 6 [Batch 300/469]	Loss: 107.368
# Train Epoch 6 [Batch 400/469]	Loss: 107.211
# =====> Epoch 6, Average Loss: 108.711
# =====> Average Test Loss: 107.414
# Train Epoch 7 [Batch 0/469]	Loss: 106.972
# Train Epoch 7 [Batch 100/469]	Loss: 105.974
# Train Epoch 7 [Batch 200/469]	Loss: 105.741
# Train Epoch 7 [Batch 300/469]	Loss: 109.623
# Train Epoch 7 [Batch 400/469]	Loss: 106.839
# =====> Epoch 7, Average Loss: 107.875
# =====> Average Test Loss: 107.068
# Train Epoch 8 [Batch 0/469]	Loss: 104.570
# Train Epoch 8 [Batch 100/469]	Loss: 102.942
# Train Epoch 8 [Batch 200/469]	Loss: 107.147
# Train Epoch 8 [Batch 300/469]	Loss: 110.956
# Train Epoch 8 [Batch 400/469]	Loss: 111.209
# =====> Epoch 8, Average Loss: 107.227
# =====> Average Test Loss: 106.269
# Train Epoch 9 [Batch 0/469]	Loss: 104.315
# Train Epoch 9 [Batch 100/469]	Loss: 103.591
# Train Epoch 9 [Batch 200/469]	Loss: 106.621
# Train Epoch 9 [Batch 300/469]	Loss: 108.898
# Train Epoch 9 [Batch 400/469]	Loss: 107.910
# =====> Epoch 9, Average Loss: 106.723
# =====> Average Test Loss: 106.227
# Train Epoch 10 [Batch 0/469]	Loss: 107.952
# Train Epoch 10 [Batch 100/469]	Loss: 107.500
# Train Epoch 10 [Batch 200/469]	Loss: 109.992
# Train Epoch 10 [Batch 300/469]	Loss: 106.035
# Train Epoch 10 [Batch 400/469]	Loss: 106.971
# =====> Epoch 10, Average Loss: 106.289
# =====> Average Test Loss: 105.643
# Train Epoch 11 [Batch 0/469]	Loss: 108.299
# Train Epoch 11 [Batch 100/469]	Loss: 107.350
# Train Epoch 11 [Batch 200/469]	Loss: 107.256
# Train Epoch 11 [Batch 300/469]	Loss: 105.794
# Train Epoch 11 [Batch 400/469]	Loss: 105.864
# =====> Epoch 11, Average Loss: 105.919
# =====> Average Test Loss: 105.425
# Train Epoch 12 [Batch 0/469]	Loss: 109.070
# Train Epoch 12 [Batch 100/469]	Loss: 104.617
# Train Epoch 12 [Batch 200/469]	Loss: 109.893
# Train Epoch 12 [Batch 300/469]	Loss: 109.220
# Train Epoch 12 [Batch 400/469]	Loss: 106.418
# =====> Epoch 12, Average Loss: 105.656
# =====> Average Test Loss: 105.095
# Train Epoch 13 [Batch 0/469]	Loss: 104.165
# Train Epoch 13 [Batch 100/469]	Loss: 105.764
# Train Epoch 13 [Batch 200/469]	Loss: 105.523
# Train Epoch 13 [Batch 300/469]	Loss: 102.736
# Train Epoch 13 [Batch 400/469]	Loss: 103.266
# =====> Epoch 13, Average Loss: 105.351
# =====> Average Test Loss: 105.071
# Train Epoch 14 [Batch 0/469]	Loss: 102.083
# Train Epoch 14 [Batch 100/469]	Loss: 110.282
# Train Epoch 14 [Batch 200/469]	Loss: 103.575
# Train Epoch 14 [Batch 300/469]	Loss: 102.337
# Train Epoch 14 [Batch 400/469]	Loss: 106.034
# =====> Epoch 14, Average Loss: 105.130
# =====> Average Test Loss: 104.664
# Train Epoch 15 [Batch 0/469]	Loss: 105.864
# Train Epoch 15 [Batch 100/469]	Loss: 105.129
# Train Epoch 15 [Batch 200/469]	Loss: 103.902
# Train Epoch 15 [Batch 300/469]	Loss: 104.163
# Train Epoch 15 [Batch 400/469]	Loss: 107.095
# =====> Epoch 15, Average Loss: 104.856
# =====> Average Test Loss: 104.683
# Train Epoch 16 [Batch 0/469]	Loss: 104.449
# Train Epoch 16 [Batch 100/469]	Loss: 105.770
# Train Epoch 16 [Batch 200/469]	Loss: 106.405
# Train Epoch 16 [Batch 300/469]	Loss: 103.121
# Train Epoch 16 [Batch 400/469]	Loss: 108.387
# =====> Epoch 16, Average Loss: 104.676
# =====> Average Test Loss: 104.327
# Train Epoch 17 [Batch 0/469]	Loss: 101.068
# Train Epoch 17 [Batch 100/469]	Loss: 105.706
# Train Epoch 17 [Batch 200/469]	Loss: 102.575
# Train Epoch 17 [Batch 300/469]	Loss: 104.482
# Train Epoch 17 [Batch 400/469]	Loss: 102.875
# =====> Epoch 17, Average Loss: 104.506
# =====> Average Test Loss: 104.104
# Train Epoch 18 [Batch 0/469]	Loss: 106.809
# Train Epoch 18 [Batch 100/469]	Loss: 102.754
# Train Epoch 18 [Batch 200/469]	Loss: 102.644
# Train Epoch 18 [Batch 300/469]	Loss: 105.151
# Train Epoch 18 [Batch 400/469]	Loss: 105.397
# =====> Epoch 18, Average Loss: 104.344
# =====> Average Test Loss: 103.953
# Train Epoch 19 [Batch 0/469]	Loss: 106.334
# Train Epoch 19 [Batch 100/469]	Loss: 105.000
# Train Epoch 19 [Batch 200/469]	Loss: 103.895
# Train Epoch 19 [Batch 300/469]	Loss: 103.017
# Train Epoch 19 [Batch 400/469]	Loss: 106.280
# =====> Epoch 19, Average Loss: 104.219
# =====> Average Test Loss: 104.163
# Train Epoch 20 [Batch 0/469]	Loss: 105.012
# Train Epoch 20 [Batch 100/469]	Loss: 108.122
# Train Epoch 20 [Batch 200/469]	Loss: 103.420
# Train Epoch 20 [Batch 300/469]	Loss: 105.886
# Train Epoch 20 [Batch 400/469]	Loss: 101.874
# =====> Epoch 20, Average Loss: 104.055
# =====> Average Test Loss: 103.935
# Train Epoch 21 [Batch 0/469]	Loss: 103.072
# Train Epoch 21 [Batch 100/469]	Loss: 101.233
# Train Epoch 21 [Batch 200/469]	Loss: 107.499
# Train Epoch 21 [Batch 300/469]	Loss: 104.231
# Train Epoch 21 [Batch 400/469]	Loss: 102.052
# =====> Epoch 21, Average Loss: 103.905
# =====> Average Test Loss: 103.643
# Train Epoch 22 [Batch 0/469]	Loss: 101.720
# Train Epoch 22 [Batch 100/469]	Loss: 106.460
# Train Epoch 22 [Batch 200/469]	Loss: 100.861
# Train Epoch 22 [Batch 300/469]	Loss: 106.033
# Train Epoch 22 [Batch 400/469]	Loss: 107.557
# =====> Epoch 22, Average Loss: 103.807
# =====> Average Test Loss: 103.478
# Train Epoch 23 [Batch 0/469]	Loss: 107.524
# Train Epoch 23 [Batch 100/469]	Loss: 102.800
# Train Epoch 23 [Batch 200/469]	Loss: 104.081
# Train Epoch 23 [Batch 300/469]	Loss: 102.534
# Train Epoch 23 [Batch 400/469]	Loss: 101.818
# =====> Epoch 23, Average Loss: 103.699
# =====> Average Test Loss: 103.592
# Train Epoch 24 [Batch 0/469]	Loss: 102.995
# Train Epoch 24 [Batch 100/469]	Loss: 101.432
# Train Epoch 24 [Batch 200/469]	Loss: 100.376
# Train Epoch 24 [Batch 300/469]	Loss: 104.316
# Train Epoch 24 [Batch 400/469]	Loss: 101.108
# =====> Epoch 24, Average Loss: 103.519
# =====> Average Test Loss: 103.479
# Train Epoch 25 [Batch 0/469]	Loss: 103.543
# Train Epoch 25 [Batch 100/469]	Loss: 103.030
# Train Epoch 25 [Batch 200/469]	Loss: 102.969
# Train Epoch 25 [Batch 300/469]	Loss: 105.033
# Train Epoch 25 [Batch 400/469]	Loss: 100.636
# =====> Epoch 25, Average Loss: 103.494
# =====> Average Test Loss: 103.349
